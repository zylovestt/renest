# %%
import numpy as np

# %%
load_dict = np.load('dic.npy',allow_pickle=True).item()

# %%
load_dict
# Out:
# {'Adam1e-3train_acc': [0.55,
#   0.5,
#   0.575,
#   0.540625,
#   0.5625,
#   0.5,
#   0.559375,
#   0.571875,
#   0.534375,
#   0.534375,
#   0.553125,
#   0.575,
#   0.540625,
#   0.490625,
#   0.565625,
#   0.59375,
#   0.553125,
#   0.615625,
#   0.6,
#   0.5625,
#   0.590625,
#   0.5375,
#   0.571875,
#   0.625,
#   0.65625,
#   0.625,
#   0.63125,
#   0.596875,
#   0.615625,
#   0.596875,
#   0.578125,
#   0.58125,
#   0.590625,
#   0.559375,
#   0.63125,
#   0.6],
#  'Adam1e-3train_loss': [0.7365974724292755,
#   0.7912514388561249,
#   0.7247151434421539,
#   0.7705213129520416,
#   0.7350346982479096,
#   0.7862157166004181,
#   0.7331356525421142,
#   0.7217437386512756,
#   0.7233194887638092,
#   0.7341236591339111,
#   0.6734902560710907,
#   0.6931721806526184,
#   0.6940949380397796,
#   0.7076096475124359,
#   0.6821077585220336,
#   0.6624900519847869,
#   0.683468759059906,
#   0.6651603281497955,
#   0.6660748600959778,
#   0.6792828619480134,
# ...
